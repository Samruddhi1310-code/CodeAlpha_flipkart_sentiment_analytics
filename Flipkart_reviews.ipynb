# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("flipkart_product_reviews.csv")
df.head()
# Out:
#                                               review
# 0  Excellent product, very satisfied with the qua...
# 1                 Worst product ever, waste of money
# 2                   Average product, nothing special
# 3              Really good quality and fast delivery
# 4                     Poor packaging and bad product

# %%
df.columns
# Out:
# Index(['review'], dtype='object')

# %%
positive_words = [
    "good","excellent","amazing","awesome","best","love","great",
    "satisfied","happy","nice","perfect","fantastic","value"
]

negative_words = [
    "bad","worst","poor","hate","terrible","disappointed",
    "unsatisfied","waste","problem","boring","broken"
]

# %%
def get_sentiment(text):
    text = str(text).lower()
    
    pos_count = sum(word in text for word in positive_words)
    neg_count = sum(word in text for word in negative_words)
    
    if pos_count > neg_count:
        return "Positive"
    elif neg_count > pos_count:
        return "Negative"
    else:
        return "Neutral"

# %%
df["Sentiment"] = df["review"].apply(get_sentiment)
df.head()
# Out:
#                                               review Sentiment
# 0  Excellent product, very satisfied with the qua...  Positive
# 1                 Worst product ever, waste of money  Negative
# 2                   Average product, nothing special   Neutral
# 3              Really good quality and fast delivery  Positive
# 4                     Poor packaging and bad product  Negative

# %%
df["Sentiment"].value_counts().plot(kind="bar", color=["green","red","gray"])
plt.title("Sentiment Distribution of Flipkart Product Reviews")
plt.xlabel("Sentiment")
plt.ylabel("Number of Reviews")
plt.show()
